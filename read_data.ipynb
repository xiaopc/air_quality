# %%
import pandas as pd

# %%
# 单一城市
# dataset = pd.read_csv('china_cities_20191020.csv')
# dataset['type'] = dataset['type'].map(lambda tag : tag.replace('.', '_').lower())
# dataset['datehour'] = dataset['date'].map(str) + dataset['hour'].map("{:0>2d}".format)
# dataset_cd = dataset.loc[:, ['datehour', 'type', '成都']]
# dataset_cd = dataset_cd.pivot(index='datehour', columns='type')
# print(dataset_cd.columns)
# print(dataset_cd)

# %%
dataset = pd.read_csv('china_cities_20191020.csv')
# 将列名的 . 换为 _ 便于导入
dataset['type'] = dataset['type'].map(lambda tag : tag.replace('.', '_').lower())
# 将日期和小时合并为 datehour
dataset['datehour'] = dataset['date'].map(str) + dataset['hour'].map("{:0>2d}".format)
dataset = dataset.drop(labels=['date', 'hour'],axis=1)
# 行列互换，列为各项检测值，行为时间地点
dataset.columns.name = 'location'
dataset = dataset.pivot(index='datehour', columns='type').stack(level=0)
# print(dataset.columns)
# print(dataset.head(50))
# Out:
# Index(['aqi', 'co', 'co_24h', 'no2', 'no2_24h', 'o3', 'o3_24h', 'o3_8h',
#        'o3_8h_24h', 'pm10', 'pm10_24h', 'pm2_5', 'pm2_5_24h', 'so2',
#        'so2_24h'],
#       dtype='object', name='type')
# type                   aqi    co  co_24h   no2  no2_24h     o3  o3_24h  o3_8h  \
# datehour   location
# 2019102000 七台河        66.0  0.73    0.70  37.0     40.0   33.0    85.0   39.0
#            三亚         53.0  0.75    0.65   9.0      8.0  156.0   157.0  150.0
#            三明         50.0  0.62    0.65  38.0     25.0   31.0   147.0   67.0
#            三门峡        55.0  1.12    0.90  41.0     29.0   16.0   104.0   49.0
#            上海         64.0  0.76    0.61  75.0     49.0   64.0   144.0   94.0
#            上饶         63.0  0.62    0.53  36.0     25.0   82.0   161.0  106.0
#            东莞         96.0  1.06    0.82  70.0     41.0   43.0   200.0  105.0
#            东营        150.0  1.12    1.32  82.0     65.0   31.0   206.0  127.0
#            中卫         91.0  0.53    0.60  67.0     36.0    6.0    90.0   36.0
#            中山         74.0  0.80    0.80  36.0     44.0  115.0   256.0  145.0
#            临夏州        59.0  0.60    1.00  28.0     22.0   35.0   107.0   64.0
#            临安         58.0  1.00    0.90  22.0     27.0   45.0   104.0   54.0
#            临汾         61.0  1.23    1.18  48.0     40.0   11.0   129.0   51.0
#            临沂        160.0  0.85    1.08  49.0     61.0   90.0   180.0  109.0
#            临沧         39.0  0.85    0.85  18.0     12.0   23.0    84.0   58.0
#            丹东         87.0  1.35    1.12  27.0     29.0   40.0   103.0   53.0
#            丽水         52.0  0.60    0.63  26.0     22.0   65.0   151.0  103.0
#            丽江         24.0  0.50    0.60   6.0     11.0   69.0    81.0   69.0
#            义乌         70.0  0.75    0.75  57.0     50.0   47.0   116.0   66.0
#            乌兰察布       82.0  0.30    0.75  15.0     44.0   72.0   113.0   78.0
#            乌海         64.0  0.97    0.93  48.0     27.0   21.0    96.0   64.0
#            乌鲁木齐       64.0  0.93    0.71  59.0     41.0   14.0    62.0   34.0
#            乐山         76.0  0.68    0.75  23.0     34.0   70.0   102.0   58.0
#            九江         70.0  0.91    0.70  61.0     41.0   46.0   163.0   78.0
#            乌兰察布           99.0  114.0      72.0   35.0       37.0   17.0
#            乌海             92.0   80.0     120.0   29.0       34.0    6.0
#            乌鲁木齐           52.0   81.0      40.0   34.0       17.0    7.0
#            乐山             86.0   64.0      55.0   56.0       42.0   15.0
#            九江            142.0   84.0      66.0   43.0       45.0   11.0
#            乳山            140.0  108.0      71.0   62.0       38.0    8.0
#            云浮            130.0   58.0      48.0   39.0       29.0   37.0
#            五家渠            61.0   42.0      37.0   12.0       15.0    8.0
#            亳州            158.0   96.0     114.0   59.0       86.0    8.0
#            伊春             74.0   30.0      36.0   17.0       14.0    5.0
#            伊犁哈萨克州         67.0  137.0      40.0   69.0       20.0   17.0
#            佛山            188.0   85.0      64.0   48.0       36.0   12.0
#            佳木斯            65.0   93.0      84.0   51.0       38.0    7.0
#            保定             89.0  216.0     170.0  168.0      127.0    7.0
#            保山             82.0   14.0      20.0   12.0       17.0    5.0
#            信阳            148.0   55.0      40.0   33.0       24.0    5.0
#            克州             90.0  112.0      68.0   34.0       19.0    9.0
#            克拉玛依           54.0   66.0      40.0   26.0       11.0    6.0
#            六安            146.0   81.0      82.0   44.0       41.0   12.0
#            六盘水            70.0   31.0      34.0   26.0       28.0    6.0
#            兰州             83.0  106.0      79.0   32.0       30.0    9.0
#            兴安盟           109.0   91.0      79.0   58.0       42.0   10.0
#            内江             84.0   43.0      47.0   33.0       32.0    5.0
#            凉山州            93.0   36.0      36.0   21.0       22.0   12.0
#            包头             79.0  268.0     124.0   68.0       51.0    6.0
#            北京             44.0  110.0      85.0  163.0      122.0    3.0
#            北海            137.0   72.0      54.0   45.0       32.0    7.0
#            十堰             89.0   52.0      49.0   25.0       27.0    7.0
#            南京            148.0   86.0      66.0   53.0       39.0    9.0
#            南充             95.0   56.0      54.0   35.0       31.0    3.0
#            南宁            102.0   89.0      59.0   44.0       27.0   13.0
#
# type                 so2_24h
# datehour   location
# 2019102000 七台河          11.0
#            三亚            5.0
#            三明            6.0
#            三门峡           7.0
#            上海            8.0
#            上饶           63.0
#            东莞           15.0
#            东营           17.0
#            中卫           10.0
#            中山           11.0
#            临夏州           9.0
#            临安            2.0
#            临汾            6.0
#            临沂           17.0
#            临沧           10.0
#            丹东           14.0
#            丽水            6.0
#            丽江            6.0
#            义乌           13.0
#            乌兰察布         24.0
#            乌海           22.0
#            乌鲁木齐          7.0
#            乐山           11.0
#            九江           11.0
#            乳山            9.0
#            云浮           21.0
#            五家渠          10.0
#            亳州            7.0
#            伊春            6.0
#            伊犁哈萨克州       12.0
#            佛山           13.0
#            佳木斯           8.0
#            保定            9.0
#            保山            5.0
#            信阳            5.0
#            克州            7.0
#            克拉玛依          6.0
#            六安            7.0
#            六盘水           8.0
#            兰州           10.0
#            兴安盟           9.0
#            内江            7.0
#            凉山州          17.0
#            包头           27.0
#            北京            2.0
#            北海           10.0
#            十堰            6.0
#            南京            9.0
#            南充            4.0
#            南宁           13.0

# %%
# 导出 csv 测试
dataset.to_csv('myDataFrame.csv')

# %%
# 导入数据库
from sqlalchemy import create_engine
con = create_engine('mysql+pymysql://root:toor@localhost:3306/air?charset=utf8')
pd.io.sql.to_sql(dataset, 'air_quality', con, schema='air', if_exists='append')
